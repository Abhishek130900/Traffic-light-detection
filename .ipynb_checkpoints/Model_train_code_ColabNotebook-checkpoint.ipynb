# %%
import os
if 'COLAB_GPU' in os.environ:
  print('GPU enable')
else:
  print('GPU Not enable')
# Out:
# GPU enable

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !mkdir projectFile

# %%
# %cd /content/drive/MyDrive/projectFile
# Out:
# /content/drive/MyDrive/projectFile

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tOPDjLAlZsgA9W3242G1")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/projectFile/Self-Driving-Cars-6/data.yaml epochs=15 imgsz=640 batch=16
# Out:
# Streaming output truncated to the last 5000 lines.
#        5/15      2.85G     0.8019       1.71      1.099         32        640:  88% 195/221 [02:20<00:15,  1.69it/s]/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:299: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        5/15      2.85G     0.8015      1.709      1.098         41        640:  89% 196/221 [02:20<00:14,  1.77it/s]/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:299: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# ...
